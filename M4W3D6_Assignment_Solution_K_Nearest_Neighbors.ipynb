# %% [markdown]
# <a href="https://colab.research.google.com/github/yaman9675/K-NN-IMDB/blob/main/M4W3D6_Assignment_Solution_K_Nearest_Neighbors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <u><b> Objective </b></u>
# ## <b>Build a recommender system which would recommend the 5 most similar movies to a movie query. </b>
#
# ### Suppose you are working at IMDB and you want to find out which movies are similar to a given movie. We can use kNN algorithm to identify the most similar movies. In the given dataset, we are given a lot of information about a particular movie. We need to restrict ourselves to the columns, Movie ID, Movie Name, IMDB Rating and binary indicators of different genres.
#
# ### A sample dataset might look like :

# %% [markdown]
# ![KNN_assignment.PNG](data:image/png;base64,...)

# %% [markdown]
# ### You can keep all the genres indicators as columns. Suppose in the column genres, you have 20 distinct genres then you will create 20 different indicators.
#
# ### Also you need to take any 1000 movies in your train dataset and 10 movies in your test corresponding to which you need to print the 5 most similar movies since kNN becomes computationally intensive as the number of observations increases.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
path='/content/drive/MyDrive/Colab Notebooks/Data/'
imdb_df=pd.read_csv(path+'imdb_data.csv')

# %%
imdb_df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
imdb_df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
imdb_df.title
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %% [markdown]
# Selectinf 1100 movies from the data set , so that we can clean and remove few

# %%
df=imdb_df[['id','genres','popularity','title']].sample(n = 1100, replace = False)

# %%
df.head()
# Out:
#         id                                             genres  popularity  \
# 2049  2050  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   11.911173
# 1463  1464  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...    9.620250
# 469    470  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...    9.231318
# 2561  2562  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    6.753969
# 903    904  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    1.833948
#
#                         title
# 2049                Anastasia
# 1463               Hard Candy
# 469   The Karate Kid, Part II
# 2561         Punch-Drunk Love
# 903                      Tank

# %%
df.dropna(inplace=True)

# %%
df['genres'] = df.apply(lambda row: eval(row['genres']), axis=1)

# %%
df.index=range(len(df))

# %%
df.head()
# Out:
#      id                                             genres  popularity  \
# 0  2050  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   11.911173
# 1  1464  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...    9.620250
# 2   470  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...    9.231318
# 3  2562  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    6.753969
# 4   904  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    1.833948
#
#                      title
# 0                Anastasia
# 1               Hard Candy
# 2  The Karate Kid, Part II
# 3         Punch-Drunk Love
# 4                     Tank

# %%
df['genres'][1]
# Out:
# [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name': 'Thriller'}]

# %%
import numpy as np

genres_list = []
for index, row in df.iterrows():
    innerlist=[]
    genre_list = df.loc[index, 'genres']
    for elem in genre_list:
        innerlist.append(elem['name'])
    genres_list.append(innerlist)

genres_list=np.array([np.array(xi) for xi in genres_list])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   # This is added back by InteractiveShellApp.init_path()

# %%
genres_list[0:5]
# Out:
# array([array(['Animation', 'Family'], dtype='<U9'),
#        array(['Drama', 'Thriller'], dtype='<U8'),
#        array(['Adventure', 'Drama', 'Action', 'Romance', 'Family'], dtype='<U9'),
#        array(['Comedy', 'Drama', 'Romance'], dtype='<U7'),
#        array(['Action', 'Adventure', 'Comedy', 'Drama', 'Thriller'], dtype='<U9')],
#       dtype=object)

# %%
df['genres_list']=genres_list

# %%
df.head()
# Out:
#      id                                             genres  popularity  \
# 0  2050  [{'id': 16, 'name': 'Animation'}, {'id': 10751...   11.911173
# 1  1464  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...    9.620250
# 2   470  [{'id': 12, 'name': 'Adventure'}, {'id': 18, '...    9.231318
# 3  2562  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    6.753969
# 4   904  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...    1.833948
#
#                      title                                   genres_list
# 0                Anastasia                           [Animation, Family]
# 1               Hard Candy                             [Drama, Thriller]
# 2  The Karate Kid, Part II   [Adventure, Drama, Action, Romance, Family]
# 3         Punch-Drunk Love                      [Comedy, Drama, Romance]
# 4                     Tank  [Action, Adventure, Comedy, Drama, Thriller]

# %%
df.drop('genres',axis=1,inplace=True)

# %%
df.head()
# Out:
#      id  popularity                    title  \
# 0  2050   11.911173                Anastasia
# 1  1464    9.620250               Hard Candy
# 2   470    9.231318  The Karate Kid, Part II
# 3  2562    6.753969         Punch-Drunk Love
# 4   904    1.833948                     Tank
#
#                                     genres_list
# 0                           [Animation, Family]
# 1                             [Drama, Thriller]
# 2   [Adventure, Drama, Action, Romance, Family]
# 3                      [Comedy, Drama, Romance]
# 4  [Action, Adventure, Comedy, Drama, Thriller]

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer(sparse_output=True)

df = df.join(
            pd.DataFrame.sparse.from_spmatrix(
                mlb.fit_transform(df.pop('genres_list')),
                index=df.index,
                columns=mlb.classes_))

# %%
column_sum= df.drop(['id','popularity'],axis=1).sum(numeric_only=True, axis=0)

# %%
import seaborn as sns
import matplotlib.colors as colors
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8),edgecolor='k',facecolor='xkcd:sky blue')
column_sum.plot(kind='bar',color='green')
plt.show()

# %% [markdown]
# Just checking for the correlation among diffrent genres

# %%
plt.figure(figsize=(18,12),edgecolor='k',facecolor='xkcd:light green')
sns.heatmap(df.corr(),annot=True,cmap='YlGnBu',linewidths=.5)

# %% [markdown]
# HArd To draw any conclusion from it

# %%
X=df.set_index('title')
X.drop(columns='id',inplace=True)
X
# Out:
#                          popularity  Action  Adventure  Animation  Comedy  \
# title
# Anastasia                 11.911173       0          0          1       0
# Hard Candy                 9.620250       0          0          0       0
# The Karate Kid, Part II    9.231318       1          1          0       0
# Punch-Drunk Love           6.753969       0          0          0       1
# Tank                       1.833948       1          1          0       1
# ...                             ...     ...        ...        ...     ...
# Used Cars                  6.963023       1          0          0       1
# Mean Girls                11.454835       0          0          0       1
# Carol                      8.364201       0          0          0       0
# Waiting for Happiness      0.352330       0          0          0       0
# Finding Forrester         10.536255       0          0          0       0
#
#                          Crime  Documentary  Drama  Family  Fantasy  Foreign  \
# title
# Anastasia                    0            0      0       1        0        0
# Hard Candy                   0            0      1       0        0        0
# The Karate Kid, Part II      0            0      1       1        0        0
# Punch-Drunk Love             0            0      1       0        0        0
# Tank                         0            0      1       0        0        0
# ...                        ...          ...    ...     ...      ...      ...
# Used Cars                    0            0      0       0        0        0
# Mean Girls                   0            0      0       0        0        0
# Carol                        0            0      1       0        0        0
# Waiting for Happiness        0            0      1       0        0        0
# Finding Forrester            0            0      1       0        0        0
#
#                          History  Horror  Music  Mystery  Romance  \
# title
# Anastasia                      0       0      0        0        0
# Hard Candy                     0       0      0        0        0
# The Karate Kid, Part II        0       0      0        0        1
# Punch-Drunk Love               0       0      0        0        1
# Tank                           0       0      0        0        0
# ...                          ...     ...    ...      ...      ...
# Used Cars                      0       0      0        0        0
# Mean Girls                     0       0      0        0        0
# Carol                          0       0      0        0        1
# Waiting for Happiness          0       0      1        0        0
# Finding Forrester              0       0      0        0        0
#
#                          Science Fiction  Thriller  War  Western
# title
# Anastasia                              0         0    0        0
# Hard Candy                             0         1    0        0
# The Karate Kid, Part II                0         0    0        0
# Punch-Drunk Love                       0         0    0        0
# Tank                                   0         1    0        0
# ...                                  ...       ...  ...      ...
# Used Cars                              0         0    0        0
# Mean Girls                             0         0    0        0
# Carol                                  0         0    0        0
# Waiting for Happiness                  0         0    0        0
# Finding Forrester                      0         0    0        0
#
# [1098 rows x 20 columns]

# %%
from scipy.sparse import csr_matrix

movie_features_df_matrix = csr_matrix(X.values)

# %%
from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = 'cosine', algorithm = 'brute')
model_knn.fit(movie_features_df_matrix)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
query_index = np.random.choice(X.shape[0])
print(query_index)
# Out:
# 682

# %%
distances, indices = model_knn.kneighbors(np.array(X.iloc[query_index,:].values).reshape(1, -1), n_neighbors = 6)

# %%
for i in range(0, len(distances.flatten())):
    if i == 0:
        print('Recommendations for {0}:\n'.format(X.index[query_index]))
    else:
        print('{0}: {1}, with distance of {2}:'.format(i, X.index[indices.flatten()[i]], distances.flatten()[i]))
# Out:
# Recommendations for Rushmore:
#
# 1: Henry Poole Is Here, with distance of 3.799813497074034e-06:
# 2: Jeff, Who Lives at Home, with distance of 1.1145902449327671e-05:
# 3: The Station Agent, with distance of 1.4715939331555461e-05:
# 4: The Player, with distance of 3.5270085890992675e-05:
# 5: Punchline, with distance of 4.047272610108177e-05:

# %%
X_test=df[1001:1010].set_index('title')
X_test.drop(columns='id',inplace=True)

# %%
test_movie=X_test.index.tolist()

# %%
for movie_name in test_movie:
    model_knn.fit(X_test)
    distances, indices = model_knn.kneighbors(np.array(X.loc[movie_name,:].values).reshape(1, -1), n_neighbors = 6)
    for i in range(0, len(distances.flatten())):
        if i == 0:
            print('Recommendations for {0}:\n'.format(movie_name))
            print()
        else:
            print('{0}: {1}, with distance of {2}:'.format(i, X.index[indices.flatten()[i]], distances.flatten()[i]))
    print()
# Out:
# Recommendations for The Hand:
#
#
# 1: The Karate Kid, Part II, with distance of 0.1618939954575822:
# 2: One Hundred Steps, with distance of 0.16718042842330472:
# 3: The Hangover Part III, with distance of 0.1951519111302772:
# 4: Hard Candy, with distance of 0.2032528605030851:
# 5: Punch-Drunk Love, with distance of 0.2278745216826772:
#
# Recommendations for Bloody Sunday:
#
#
# 1: One Hundred Steps, with distance of 0.02619073659064486:
# 2: The Hangover Part III, with distance of 0.02904371256314664:
# 3: Punch-Drunk Love, with distance of 0.03630192337037885:
# 4: The Karate Kid, Part II, with distance of 0.04046758521836524:
# 5: Rio Bravo, with distance of 0.057899686535400785:
#
# Recommendations for Jeepers Creepers:
#
#
# 1: Punch-Drunk Love, with distance of 0.013843532737723208:
# 2: The Hangover Part III, with distance of 0.01942172031510203:
# 3: One Hundred Steps, with distance of 0.028917344430775982:
# 4: Rio Bravo, with distance of 0.03594461848241448:
# 5: Hard Candy, with distance of 0.04046758521836524:
#
# Recommendations for The First Wives Club:
#
#
# 1: The Karate Kid, Part II, with distance of 0.013843532737723208:
# 2: The Hangover Part III, with distance of 0.0151646910936587:
# 3: Rio Bravo, with distance of 0.015771994172922632:
# 4: One Hundred Steps, with distance of 0.024701538995514416:
# 5: Hard Candy, with distance of 0.03630192337037885:
#
# Recommendations for Arthur 2: On the Rocks:
#
#
# 1: Rio Bravo, with distance of 0.009771938251856294:
# 2: Punch-Drunk Love, with distance of 0.04809787486911121:
# 3: The Karate Kid, Part II, with distance of 0.0773162739401102:
# 4: The Hangover Part III, with distance of 0.07855239757265498:
# 5: One Hundred Steps, with distance of 0.0874754180557833:
#
# Recommendations for Cool Hand Luke:
#
#
# 1: One Hundred Steps, with distance of 0.009953602685383145:
# 2: Punch-Drunk Love, with distance of 0.0151646910936587:
# 3: The Karate Kid, Part II, with distance of 0.01942172031510203:
# 4: Hard Candy, with distance of 0.02904371256314664:
# 5: Rio Bravo, with distance of 0.03723616791210338:
#
# Recommendations for Chasing Liberty:
#
#
# 1: Tank, with distance of 0.009771938251856294:
# 2: Punch-Drunk Love, with distance of 0.015771994172922632:
# 3: The Karate Kid, Part II, with distance of 0.03594461848241448:
# 4: The Hangover Part III, with distance of 0.03723616791210338:
# 5: One Hundred Steps, with distance of 0.04655928229376216:
#
# Recommendations for Born to Be Wild:
#
#
# 1: Punch-Drunk Love, with distance of 0.05834386930851121:
# 2: The Karate Kid, Part II, with distance of 0.06241425308603488:
# 3: The Hangover Part III, with distance of 0.06367034102447355:
# 4: One Hundred Steps, with distance of 0.07273747485171456:
# 5: Rio Bravo, with distance of 0.07944764297660178:
#
# Recommendations for Dragonfly:
#
#
# 1: The Hangover Part III, with distance of 0.009953602685383145:
# 2: Punch-Drunk Love, with distance of 0.024701538995514416:
# 3: Hard Candy, with distance of 0.02619073659064486:
# 4: The Karate Kid, Part II, with distance of 0.028917344430775982:
# 5: Rio Bravo, with distance of 0.04655928229376216:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."

# %% [markdown]
# This is how we are able to genrate recomendations using knn

# %%
from sklearn.neighbors import NearestNeighbors


model_knn = NearestNeighbors(metric = 'minkowski', algorithm = 'auto')
model_knn.fit(movie_features_df_matrix)
# Out:
# NearestNeighbors()

# %%
for movie_name in test_movie:
    model_knn.fit(X_test)
    distances, indices = model_knn.kneighbors(np.array(X.loc[movie_name,:].values).reshape(1, -1), n_neighbors = 6)
    for i in range(0, len(distances.flatten())):
        if i == 0:
            print('Recommendations for {0}:\n'.format(movie_name))
            print()
        else:
            print('{0}: {1}, with distance of {2}:'.format(i, X.index[indices.flatten()[i]], distances.flatten()[i]))
    print()
# Out:
# Recommendations for The Hand:
#
#
# 1: Bend It Like Beckham, with distance of 2.151837410307758:
# 2: Tank, with distance of 2.6823551075443013:
# 3: One Hundred Steps, with distance of 3.1316906902412955:
# 4: Rio Bravo, with distance of 4.427108773635903:
# 5: Hard Candy, with distance of 6.055959287225188:
#
# Recommendations for Bloody Sunday:
#
#
# 1: The Hangover Part III, with distance of 2.800845700855372:
# 2: Rio Bravo, with distance of 3.0439589860313507:
# 3: Punch-Drunk Love, with distance of 3.2944571589413654:
# 4: One Hundred Steps, with distance of 3.321237842616065:
# 5: The Karate Kid, Part II, with distance of 3.613409276915638:
#
# Recommendations for Jeepers Creepers:
#
#
# 1: Punch-Drunk Love, with distance of 1.7481983421797462:
# 2: The Hangover Part III, with distance of 2.1175289661537096:
# 3: Hard Candy, with distance of 3.613409276915638:
# 4: Rio Bravo, with distance of 4.891162036984769:
# 5: One Hundred Steps, with distance of 5.757015666230638:
#
# Recommendations for The First Wives Club:
#
#
# 1: The Karate Kid, Part II, with distance of 1.7481983421797462:
# 2: The Hangover Part III, with distance of 1.791732342762167:
# 3: Hard Candy, with distance of 3.2944571589413654:
# 4: Rio Bravo, with distance of 4.343201035310363:
# 5: One Hundred Steps, with distance of 5.4402548562199735:
#
# Recommendations for Arthur 2: On the Rocks:
#
#
# 1: Bend It Like Beckham, with distance of 1.8635370621184322:
# 2: One Hundred Steps, with distance of 2.173242828269543:
# 3: Rio Bravo, with distance of 2.339338999999999:
# 4: Anastasia, with distance of 2.6823551075443013:
# 5: Hard Candy, with distance of 4.815924680847907:
#
# Recommendations for Cool Hand Luke:
#
#
# 1: Punch-Drunk Love, with distance of 1.791732342762167:
# 2: The Karate Kid, Part II, with distance of 2.1175289661537096:
# 3: Hard Candy, with distance of 2.800845700855372:
# 4: Rio Bravo, with distance of 4.265820983379519:
# 5: One Hundred Steps, with distance of 4.897808161129324:
#
# Recommendations for Chasing Liberty:
#
#
# 1: One Hundred Steps, with distance of 2.0134899149973413:
# 2: Tank, with distance of 2.3393389999999985:
# 3: Hard Candy, with distance of 3.0439589860313507:
# 4: Bend It Like Beckham, with distance of 3.487442729864391:
# 5: The Hangover Part III, with distance of 4.265820983379519:
#
# Recommendations for Born to Be Wild:
#
#
# 1: Tank, with distance of 1.8635370621184322:
# 2: Anastasia, with distance of 2.151837410307758:
# 3: One Hundred Steps, with distance of 2.4496595770155496:
# 4: Rio Bravo, with distance of 3.487442729864391:
# 5: Hard Candy, with distance of 5.326159190809923:
#
# Recommendations for Dragonfly:
#
#
# 1: Rio Bravo, with distance of 2.0134899149973413:
# 2: Tank, with distance of 2.1732428282695424:
# 3: Bend It Like Beckham, with distance of 2.4496595770155496:
# 4: Anastasia, with distance of 3.1316906902412955:
# 5: Hard Candy, with distance of 3.321237842616065:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'str_']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:625: UserWarning: pandas.DataFrame with sparse columns found.It will be converted to a dense numpy array.
#   "pandas.DataFrame with sparse columns found."
